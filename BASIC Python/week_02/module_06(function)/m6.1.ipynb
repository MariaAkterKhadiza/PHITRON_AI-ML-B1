# %% [markdown]
# function pararmeter(input)

# %%
def great(user = "guest"):
    print(f"hello {user}")
great("Maria")
# Out:
# hello Maria

# %%
def square_addition(a,b):
    a = a**2
    b = b**2
    return(a+b)

ans = square_addition(10,20) + 10
print(ans)
# Out:
# 510
